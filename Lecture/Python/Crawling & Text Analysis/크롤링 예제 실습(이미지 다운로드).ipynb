# %%
import urllib.request

# %%
url = "https://happybean-phinf.pstatic.net/20200625_240/1593072023443dofAk_JPEG/00.jpg?type=w720"
filename = "image.jpeg"
urllib.request.urlretrieve(url, filename)
# Out:
# ('image.jpeg', <http.client.HTTPMessage at 0x228edc1e108>)

# %%
url = "https://happybean-phinf.pstatic.net/20200625_240/1593072023443dofAk_JPEG/00.jpg?type=w720"
filename = "image2.jpeg"
urllib.request.urlretrieve(url, filename)

mem = urllib.request.urlopen(url).read()
with open(filename, mode = "wb") as f:
    f.write(mem)

# %%
mem #16진수로 저장된 이미지 파일
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x01\xe0\x02\xd0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x01\x05\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x02\x04\x05\x06\x07\x01\x08\x00\t\xff\xc4\x00H\x10\x00\x01\x03\x03\x02\x04\x04\x04\x04\x04\x05\x03\x02\x04\x05\x05\x01\x00\x02\x03\x04\x05\x11\x06!\x07\x121A\x13"Qa\x142q\x91\x08BR\x81\x15#\xa1\xb1\x16$3b\xc1Cr\xd1%S&4c\xe1\x17\x185s\x926
# ...

# %%
import io #문자열을 숫자로 변환
from PIL import Image #화면에 이미지를 출력

# %%
Image.open(io.BytesIO(mem))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x228EED5FAC8>
